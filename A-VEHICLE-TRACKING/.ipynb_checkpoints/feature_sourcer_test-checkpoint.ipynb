# %%
import sys
sys.path.append('..')
sys.path
# Out:
# ['',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2\\python27.zip',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2\\DLLs',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2\\lib',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2\\lib\\plat-win',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2\\lib\\lib-tk',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2\\lib\\site-packages',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2\\lib\\site-packages\\win32',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\Gagan Aggawal\\Anaconda2\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Gagan Aggawal\\.ipython',
#  '..',
#  '..',
#  '..',
#  '..',
#  '..',
#  '..']

# %%
from scipy.misc import imread
from sklearn.externals import joblib

import random as rand
import numpy as np 
import cv2
import glob
import time

import matplotlib.pyplot as plt
# %matplotlib inline

from helpers import convert, show_images
from featuresourcer import FeatureSourcer

# %%
sourcer_params = {
  'color_model': 'hls',                # HSL, HSV
  'bounding_box_size': 64,             #
  'number_of_orientations': 12,        # 6 - 12
  'pixels_per_cell': 8,                # 8, 16
  'cells_per_block': 2,                # 1, 2
  'do_transform_sqrt': True
}

# %%
start_frame = imread("../vehicles/vehicles/KITTI_extracted/5364.png")
sourcer = FeatureSourcer(sourcer_params, start_frame)

f = sourcer.features(start_frame)
print("feature shape:", f.shape)

rgb_img, a_img, b_img, c_img = sourcer.visualize()
show_images([rgb_img, a_img, b_img, c_img], per_row = 4, per_col = 1, W = 10, H = 2)
# Out:
# C:\Users\Gagan Aggawal\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# ('feature shape:', (7056L,))

# %%
start_frame = imread("../non-vehicles/non-vehicles/Extras/extra4846.png")
sourcer = FeatureSourcer(sourcer_params, start_frame)

f = sourcer.features(start_frame)
print("feature shape:", f.shape)

rgb_img, a_img, b_img, c_img = sourcer.visualize()
show_images([rgb_img, a_img, b_img, c_img], per_row = 4, per_col = 1, W = 10, H = 2)
# Out:
# C:\Users\Gagan Aggawal\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# ('feature shape:', (7056L,))
